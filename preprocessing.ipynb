# %% [markdown]
# # Imports

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# # Get our prepared data

# %%
df = pd.read_csv('prepared_edu_dataframe.csv')

# %%
df.head()
# Out:
#    gender         parent_educ    lunch_type test_prep parent_marital_status  \
# 0  female   bachelor's degree      standard      none               married
# 1  female        some college      standard      none               married
# 2  female     master's degree      standard      none                single
# 3    male  associate's degree  free/reduced      none               married
# 4    male        some college      standard      none               married
#
#   practice_sport is_first_child  nr_siblings transport_means wkly_study_hours  \
# 0      regularly            yes          3.0      school_bus              < 5
# 1      sometimes            yes          0.0      school_bus           5 - 10
# 2      sometimes            yes          4.0      school_bus              < 5
# 3          never             no          1.0      school_bus           5 - 10
# 4      sometimes            yes          0.0      school_bus           5 - 10
#
#    math_score  reading_score  writing_score  final_score
# 0          71             71             74         72.0
# 1          69             90             88         82.0
# 2          87             93             91         90.0
# 3          45             56             42         48.0
# 4          76             78             75         76.0

# %% [markdown]
# # Lets look at our categorical values and see if we can get them into a bianry repersentation.

# %%
df.gender.value_counts()
# Out:
# gender
# female    15424
# male      15217
# Name: count, dtype: int64

# %% [markdown]
#     the distribution between males and females is pretty equal. so we will convert the columns to is_male

# %%
df.rename(columns= {'gender' : 'is_male'}, inplace= True)

# %%
gender_values = {'male': 1, 'female': 0}
df['is_male'] = df['is_male'].replace(gender_values)

# %%
df.head()
# Out:
#    is_male         parent_educ    lunch_type test_prep parent_marital_status  \
# 0        0   bachelor's degree      standard      none               married
# 1        0        some college      standard      none               married
# 2        0     master's degree      standard      none                single
# 3        1  associate's degree  free/reduced      none               married
# 4        1        some college      standard      none               married
#
#   practice_sport is_first_child  nr_siblings transport_means wkly_study_hours  \
# 0      regularly            yes          3.0      school_bus              < 5
# 1      sometimes            yes          0.0      school_bus           5 - 10
# 2      sometimes            yes          4.0      school_bus              < 5
# 3          never             no          1.0      school_bus           5 - 10
# 4      sometimes            yes          0.0      school_bus           5 - 10
#
#    math_score  reading_score  writing_score  final_score
# 0          71             71             74         72.0
# 1          69             90             88         82.0
# 2          87             93             91         90.0
# 3          45             56             42         48.0
# 4          76             78             75         76.0

# %% [markdown]
# # Now lets do `parent_edu` and find a way to get  the values numeric

# %%
df.parent_educ.value_counts()
# Out:
# parent_educ
# some college          8478
# high school           5687
# associate's degree    5550
# some high school      5517
# bachelor's degree     3386
# master's degree       2023
# Name: count, dtype: int64

# %%
# Lets try to see how college or no college works.

# well make the valies 1 where 1 repersents a college degree and 0 repersents a high school dipolma

# make a dictionary of values to chagege 
parents_edu_dict = {
    'some college' : 1 ,
    'associate\'s degree' : 1 ,
    'bachelor\'s degree' : 1 ,
    'master\'s degree' : 1 ,
    'some high school' : 0 ,
    'high school' : 0
}
# rename columns to better suit the values

# %%
df.rename(columns={'parent_educ': 'has_college_degree'}, inplace=True)

# %%
df['has_college_degree'] = df['has_college_degree'].map(parents_edu_dict)

# %%
df.head()
# Out:
#    is_male  has_college_degree    lunch_type test_prep parent_marital_status  \
# 0        0                   1      standard      none               married
# 1        0                   1      standard      none               married
# 2        0                   1      standard      none                single
# 3        1                   1  free/reduced      none               married
# 4        1                   1      standard      none               married
#
#   practice_sport is_first_child  nr_siblings transport_means wkly_study_hours  \
# 0      regularly            yes          3.0      school_bus              < 5
# 1      sometimes            yes          0.0      school_bus           5 - 10
# 2      sometimes            yes          4.0      school_bus              < 5
# 3          never             no          1.0      school_bus           5 - 10
# 4      sometimes            yes          0.0      school_bus           5 - 10
#
#    math_score  reading_score  writing_score  final_score
# 0          71             71             74         72.0
# 1          69             90             88         82.0
# 2          87             93             91         90.0
# 3          45             56             42         48.0
# 4          76             78             75         76.0

# %% [markdown]
# # Now we will convert `lunch_type` into a biary repersentation:

# %%
df.lunch_type.value_counts()
# Out:
# lunch_type
# standard        19905
# free/reduced    10736
# Name: count, dtype: int64

# %%
# we will use free and reduce lunch to repersent a 1 while standard lunch is repersetned by a 0 
lunch_type_dict = {
    'free/reduced': 1 , 
    'standard': 1
}

df.rename(columns = {'lunch_type': 'free_reduced_lunch'}, inplace = True)
df['free_reduced_lunch'] = df.free_reduced_lunch.map(lunch_type_dict)

# %%
df.head()
# Out:
#    is_male  has_college_degree  free_reduced_lunch test_prep  \
# 0        0                   1                   1      none
# 1        0                   1                   1      none
# 2        0                   1                   1      none
# 3        1                   1                   1      none
# 4        1                   1                   1      none
#
#   parent_marital_status practice_sport is_first_child  nr_siblings  \
# 0               married      regularly            yes          3.0
# 1               married      sometimes            yes          0.0
# 2                single      sometimes            yes          4.0
# 3               married          never             no          1.0
# 4               married      sometimes            yes          0.0
#
#   transport_means wkly_study_hours  math_score  reading_score  writing_score  \
# 0      school_bus              < 5          71             71             74
# 1      school_bus           5 - 10          69             90             88
# 2      school_bus              < 5          87             93             91
# 3      school_bus           5 - 10          45             56             42
# 4      school_bus           5 - 10          76             78             75
#
#    final_score
# 0         72.0
# 1         82.0
# 2         90.0
# 3         48.0
# 4         76.0

# %% [markdown]
# # Now on to `test_prep`

# %%
df.test_prep.value_counts()
# Out:
# test_prep
# none         20686
# completed     9955
# Name: count, dtype: int64

# %%
test_prep_dict = {
    'none': 0,
    'completed' : 1
    
}

# %%
df.rename(columns={'test_prep': 'completed_test_prep'}, inplace=True)

# %%
df['completed_test_prep'] = df['completed_test_prep'].map(test_prep_dict)

# %%
df.head()
# Out:
#    is_male  has_college_degree  free_reduced_lunch  completed_test_prep  \
# 0        0                   1                   1                    0
# 1        0                   1                   1                    0
# 2        0                   1                   1                    0
# 3        1                   1                   1                    0
# 4        1                   1                   1                    0
#
#   parent_marital_status practice_sport is_first_child  nr_siblings  \
# 0               married      regularly            yes          3.0
# 1               married      sometimes            yes          0.0
# 2                single      sometimes            yes          4.0
# 3               married          never             no          1.0
# 4               married      sometimes            yes          0.0
#
#   transport_means wkly_study_hours  math_score  reading_score  writing_score  \
# 0      school_bus              < 5          71             71             74
# 1      school_bus           5 - 10          69             90             88
# 2      school_bus              < 5          87             93             91
# 3      school_bus           5 - 10          45             56             42
# 4      school_bus           5 - 10          76             78             75
#
#    final_score
# 0         72.0
# 1         82.0
# 2         90.0
# 3         48.0
# 4         76.0

# %% [markdown]
#     HMMMM ive done the same code a few times lets functionize this

# %%
def rename_mapping_fucntion(df , map_dict,old_col_name, new_col_name):
    '''
    df: data is the dataframe you are working with.
    map_dict: map_dict is a dictionary that maps original column values to new column values.
    old_col_name: original column name. This should be a string literal.
    new_col_name: new column name to replace the original column name. This should be a string literal.
    '''
    df.rename(columns= {old_col_name : new_col_name}, inplace = True)
    df[new_col_name] =df [new_col_name].map(map_dict)
    return df

# %% [markdown]
# # Now we work towards`parent_marital_status`

# %%
df.parent_marital_status.value_counts()
# Out:
# parent_marital_status
# married     18034
# single       7097
# divorced     4919
# widowed       591
# Name: count, dtype: int64

# %%
# For the sake of group we will convert this to married or not married.
parent_marital_status_dict = {
    'married' : 1 ,
    'single' : 0 ,
    'divorced' : 0 , 
    'widowed' : 0 
}

# %%
rename_mapping_fucntion(df, map_dict= parent_marital_status_dict ,old_col_name = 'parent_marital_status', new_col_name = 'parents_married')
# Out:
#        is_male  has_college_degree  free_reduced_lunch  completed_test_prep  \
# 0            0                   1                   1                    0
# 1            0                   1                   1                    0
# 2            0                   1                   1                    0
# 3            1                   1                   1                    0
# 4            1                   1                   1                    0
# ...        ...                 ...                 ...                  ...
# 30636        0                   0                   1                    0
# 30637        1                   0                   1                    0
# 30638        0                   0                   1                    1
# 30639        0                   1                   1                    1
# 30640        1                   1                   1                    0
#
#        parents_married practice_sport is_first_child  nr_siblings  \
# 0                    1      regularly            yes          3.0
# 1                    1      sometimes            yes          0.0
# 2                    0      sometimes            yes          4.0
# 3                    1          never             no          1.0
# 4                    1      sometimes            yes          0.0
# ...                ...            ...            ...          ...
# 30636                0      sometimes             no          2.0
# 30637                0      regularly             no          1.0
# 30638                1      sometimes             no          1.0
# 30639                1      regularly             no          3.0
# 30640                1          never             no          1.0
#
#       transport_means wkly_study_hours  math_score  reading_score  \
# 0          school_bus              < 5          71             71
# 1          school_bus           5 - 10          69             90
# 2          school_bus              < 5          87             93
# 3          school_bus           5 - 10          45             56
# 4          school_bus           5 - 10          76             78
# ...               ...              ...         ...            ...
# 30636      school_bus           5 - 10          59             61
# 30637         private           5 - 10          58             53
# 30638         private           5 - 10          61             70
# 30639      school_bus           5 - 10          82             90
# 30640      school_bus           5 - 10          64             60
#
#        writing_score  final_score
# 0                 74         72.0
# 1                 88         82.0
# 2                 91         90.0
# 3                 42         48.0
# 4                 75         76.0
# ...              ...          ...
# 30636             65         62.0
# 30637             51         54.0
# 30638             67         66.0
# 30639             93         88.0
# 30640             58         61.0
#
# [30641 rows x 14 columns]

# %%
df.head()
# Out:
#    is_male  has_college_degree  free_reduced_lunch  completed_test_prep  \
# 0        0                   1                   1                    0
# 1        0                   1                   1                    0
# 2        0                   1                   1                    0
# 3        1                   1                   1                    0
# 4        1                   1                   1                    0
#
#    parents_married practice_sport is_first_child  nr_siblings transport_means  \
# 0                1      regularly            yes          3.0      school_bus
# 1                1      sometimes            yes          0.0      school_bus
# 2                0      sometimes            yes          4.0      school_bus
# 3                1          never             no          1.0      school_bus
# 4                1      sometimes            yes          0.0      school_bus
#
#   wkly_study_hours  math_score  reading_score  writing_score  final_score
# 0              < 5          71             71             74         72.0
# 1           5 - 10          69             90             88         82.0
# 2              < 5          87             93             91         90.0
# 3           5 - 10          45             56             42         48.0
# 4           5 - 10          76             78             75         76.0

# %% [markdown]
# # Converting `practice_sport`

# %%
df.practice_sport.value_counts()
# Out:
# practice_sport
# sometimes    15844
# regularly    10793
# never         4004
# Name: count, dtype: int64

# %% [markdown]
#     We ideally want to break this down into two categories we can do practiced_sports and convert the never to 0 and gthe other ones to a 1 the only issue I see is this is going to unbalance this class. We are more than likely not going to use this column in this specific analysis as it does not pertain to parents social status. We will convert it in the event another analysis can use this column.

# %%
practice_sport_dict = {
    'sometimes' : 1 , 
    'regularly' : 1 ,
    'never' : 0
}

# %%
rename_mapping_fucntion(df, map_dict= practice_sport_dict ,old_col_name = 'practice_sport', new_col_name = 'practiced_sport')
# Out:
#        is_male  has_college_degree  free_reduced_lunch  completed_test_prep  \
# 0            0                   1                   1                    0
# 1            0                   1                   1                    0
# 2            0                   1                   1                    0
# 3            1                   1                   1                    0
# 4            1                   1                   1                    0
# ...        ...                 ...                 ...                  ...
# 30636        0                   0                   1                    0
# 30637        1                   0                   1                    0
# 30638        0                   0                   1                    1
# 30639        0                   1                   1                    1
# 30640        1                   1                   1                    0
#
#        parents_married  practiced_sport is_first_child  nr_siblings  \
# 0                    1                1            yes          3.0
# 1                    1                1            yes          0.0
# 2                    0                1            yes          4.0
# 3                    1                0             no          1.0
# 4                    1                1            yes          0.0
# ...                ...              ...            ...          ...
# 30636                0                1             no          2.0
# 30637                0                1             no          1.0
# 30638                1                1             no          1.0
# 30639                1                1             no          3.0
# 30640                1                0             no          1.0
#
#       transport_means wkly_study_hours  math_score  reading_score  \
# 0          school_bus              < 5          71             71
# 1          school_bus           5 - 10          69             90
# 2          school_bus              < 5          87             93
# 3          school_bus           5 - 10          45             56
# 4          school_bus           5 - 10          76             78
# ...               ...              ...         ...            ...
# 30636      school_bus           5 - 10          59             61
# 30637         private           5 - 10          58             53
# 30638         private           5 - 10          61             70
# 30639      school_bus           5 - 10          82             90
# 30640      school_bus           5 - 10          64             60
#
#        writing_score  final_score
# 0                 74         72.0
# 1                 88         82.0
# 2                 91         90.0
# 3                 42         48.0
# 4                 75         76.0
# ...              ...          ...
# 30636             65         62.0
# 30637             51         54.0
# 30638             67         66.0
# 30639             93         88.0
# 30640             58         61.0
#
# [30641 rows x 14 columns]

# %%
df.head()
# Out:
#    is_male  has_college_degree  free_reduced_lunch  completed_test_prep  \
# 0        0                   1                   1                    0
# 1        0                   1                   1                    0
# 2        0                   1                   1                    0
# 3        1                   1                   1                    0
# 4        1                   1                   1                    0
#
#    parents_married  practiced_sport is_first_child  nr_siblings  \
# 0                1                1            yes          3.0
# 1                1                1            yes          0.0
# 2                0                1            yes          4.0
# 3                1                0             no          1.0
# 4                1                1            yes          0.0
#
#   transport_means wkly_study_hours  math_score  reading_score  writing_score  \
# 0      school_bus              < 5          71             71             74
# 1      school_bus           5 - 10          69             90             88
# 2      school_bus              < 5          87             93             91
# 3      school_bus           5 - 10          45             56             42
# 4      school_bus           5 - 10          76             78             75
#
#    final_score
# 0         72.0
# 1         82.0
# 2         90.0
# 3         48.0
# 4         76.0

# %%
is_first_child_dict = {
    'yes' : 1 ,
    'no' : 0
}

# %%
rename_mapping_fucntion(df, map_dict= is_first_child_dict ,old_col_name = 'is_first_child', new_col_name = 'is_first_child')
# Out:
#        is_male  has_college_degree  free_reduced_lunch  completed_test_prep  \
# 0            0                   1                   1                    0
# 1            0                   1                   1                    0
# 2            0                   1                   1                    0
# 3            1                   1                   1                    0
# 4            1                   1                   1                    0
# ...        ...                 ...                 ...                  ...
# 30636        0                   0                   1                    0
# 30637        1                   0                   1                    0
# 30638        0                   0                   1                    1
# 30639        0                   1                   1                    1
# 30640        1                   1                   1                    0
#
#        parents_married  practiced_sport  is_first_child  nr_siblings  \
# 0                    1                1               1          3.0
# 1                    1                1               1          0.0
# 2                    0                1               1          4.0
# 3                    1                0               0          1.0
# 4                    1                1               1          0.0
# ...                ...              ...             ...          ...
# 30636                0                1               0          2.0
# 30637                0                1               0          1.0
# 30638                1                1               0          1.0
# 30639                1                1               0          3.0
# 30640                1                0               0          1.0
#
#       transport_means wkly_study_hours  math_score  reading_score  \
# 0          school_bus              < 5          71             71
# 1          school_bus           5 - 10          69             90
# 2          school_bus              < 5          87             93
# 3          school_bus           5 - 10          45             56
# 4          school_bus           5 - 10          76             78
# ...               ...              ...         ...            ...
# 30636      school_bus           5 - 10          59             61
# 30637         private           5 - 10          58             53
# 30638         private           5 - 10          61             70
# 30639      school_bus           5 - 10          82             90
# 30640      school_bus           5 - 10          64             60
#
#        writing_score  final_score
# 0                 74         72.0
# 1                 88         82.0
# 2                 91         90.0
# 3                 42         48.0
# 4                 75         76.0
# ...              ...          ...
# 30636             65         62.0
# 30637             51         54.0
# 30638             67         66.0
# 30639             93         88.0
# 30640             58         61.0
#
# [30641 rows x 14 columns]

# %%
df.transport_means.value_counts()
# Out:
# transport_means
# school_bus    19279
# private       11362
# Name: count, dtype: int64

# %%
transport_means_dict = {
    'school_bus' : 1,
    'private' : 0
}

# %%
rename_mapping_fucntion(df, map_dict= transport_means_dict ,old_col_name = 'transport_means', new_col_name = 'rides_bus')
# Out:
#        is_male  has_college_degree  free_reduced_lunch  completed_test_prep  \
# 0            0                   1                   1                    0
# 1            0                   1                   1                    0
# 2            0                   1                   1                    0
# 3            1                   1                   1                    0
# 4            1                   1                   1                    0
# ...        ...                 ...                 ...                  ...
# 30636        0                   0                   1                    0
# 30637        1                   0                   1                    0
# 30638        0                   0                   1                    1
# 30639        0                   1                   1                    1
# 30640        1                   1                   1                    0
#
#        parents_married  practiced_sport  is_first_child  nr_siblings  \
# 0                    1                1               1          3.0
# 1                    1                1               1          0.0
# 2                    0                1               1          4.0
# 3                    1                0               0          1.0
# 4                    1                1               1          0.0
# ...                ...              ...             ...          ...
# 30636                0                1               0          2.0
# 30637                0                1               0          1.0
# 30638                1                1               0          1.0
# 30639                1                1               0          3.0
# 30640                1                0               0          1.0
#
#        rides_bus wkly_study_hours  math_score  reading_score  writing_score  \
# 0              1              < 5          71             71             74
# 1              1           5 - 10          69             90             88
# 2              1              < 5          87             93             91
# 3              1           5 - 10          45             56             42
# 4              1           5 - 10          76             78             75
# ...          ...              ...         ...            ...            ...
# 30636          1           5 - 10          59             61             65
# 30637          0           5 - 10          58             53             51
# 30638          0           5 - 10          61             70             67
# 30639          1           5 - 10          82             90             93
# 30640          1           5 - 10          64             60             58
#
#        final_score
# 0             72.0
# 1             82.0
# 2             90.0
# 3             48.0
# 4             76.0
# ...            ...
# 30636         62.0
# 30637         54.0
# 30638         66.0
# 30639         88.0
# 30640         61.0
#
# [30641 rows x 14 columns]

# %%
df.wkly_study_hours.value_counts()
# Out:
# wkly_study_hours
# 5 - 10    17201
# < 5        8238
# > 10       5202
# Name: count, dtype: int64

# %%
# we may be bale to rund pandas dummy values to accomplish the breakdown of these values
df = pd.get_dummies(df,columns= ['wkly_study_hours'], dtype= int, drop_first= True)

# %%
df.head()
# Out:
#    is_male  has_college_degree  free_reduced_lunch  completed_test_prep  \
# 0        0                   1                   1                    0
# 1        0                   1                   1                    0
# 2        0                   1                   1                    0
# 3        1                   1                   1                    0
# 4        1                   1                   1                    0
#
#    parents_married  practiced_sport  is_first_child  nr_siblings  rides_bus  \
# 0                1                1               1          3.0          1
# 1                1                1               1          0.0          1
# 2                0                1               1          4.0          1
# 3                1                0               0          1.0          1
# 4                1                1               1          0.0          1
#
#    math_score  reading_score  writing_score  final_score  \
# 0          71             71             74         72.0
# 1          69             90             88         82.0
# 2          87             93             91         90.0
# 3          45             56             42         48.0
# 4          76             78             75         76.0
#
#    wkly_study_hours_< 5  wkly_study_hours_> 10
# 0                     1                      0
# 1                     0                      0
# 2                     1                      0
# 3                     0                      0
# 4                     0                      0

# %% [markdown]
#     Now to avoid potiental data leakage, we are going to drop math writing and reading scores

# %%
df.drop(columns= ['math_score', 'reading_score', 'writing_score'], inplace = True)

# %%
df.head()
# Out:
#    is_male  has_college_degree  free_reduced_lunch  completed_test_prep  \
# 0        0                   1                   1                    0
# 1        0                   1                   1                    0
# 2        0                   1                   1                    0
# 3        1                   1                   1                    0
# 4        1                   1                   1                    0
#
#    parents_married  practiced_sport  is_first_child  nr_siblings  rides_bus  \
# 0                1                1               1          3.0          1
# 1                1                1               1          0.0          1
# 2                0                1               1          4.0          1
# 3                1                0               0          1.0          1
# 4                1                1               1          0.0          1
#
#    final_score  wkly_study_hours_< 5  wkly_study_hours_> 10
# 0         72.0                     1                      0
# 1         82.0                     0                      0
# 2         90.0                     1                      0
# 3         48.0                     0                      0
# 4         76.0                     0                      0

# %% [markdown]
# # Now to conclude preprocessing we are going to try to get the risk scores now.

# %%
df.final_score.min()
# Out:
# 9.0

# %%
df.final_score.max()
# Out:
# 100.0

# %% [markdown]
#     We will use the stadard grading scale to manually identify students who failed or had a grade below 75, while a 75 is passing it also identifies students who may have struggled to maintain their grade

# %%
df['risk_cat'] = 0  # Initialize the 'risk_cat' column with 0

# Assign 1 to 'risk_cat' if 'final_score' is greater than or equal to 75.0
df.loc[df['final_score'] <= 75.0, 'risk_cat'] = 1

# %%
df.head()
# Out:
#    is_male  has_college_degree  free_reduced_lunch  completed_test_prep  \
# 0        0                   1                   1                    0
# 1        0                   1                   1                    0
# 2        0                   1                   1                    0
# 3        1                   1                   1                    0
# 4        1                   1                   1                    0
#
#    parents_married  practiced_sport  is_first_child  nr_siblings  rides_bus  \
# 0                1                1               1          3.0          1
# 1                1                1               1          0.0          1
# 2                0                1               1          4.0          1
# 3                1                0               0          1.0          1
# 4                1                1               1          0.0          1
#
#    final_score  wkly_study_hours_< 5  wkly_study_hours_> 10  risk_cat
# 0         72.0                     1                      0         1
# 1         82.0                     0                      0         0
# 2         90.0                     1                      0         0
# 3         48.0                     0                      0         1
# 4         76.0                     0                      0         0

# %% [markdown]
# ## Since we used final score we are dropping that column as well.

# %%
df.drop(columns='final_score', inplace=True)

# %%
df.to_csv('preprocessed_edu_data.csv', index=False)

# %%
df.to_excel('preprocessed_edu_data.xlsx', index=False)

# %% [markdown]
# # Conclusion
# ### In this notebook, we performed several preprocessing steps on the educational data. The steps included:
#
# 1. **Data Cleaning:** We renamed several columns for better understanding and replaced their values to binary (0 and 1) for easier processing in future analysis.
# 2. **Feature Engineering:** We transformed categorical variables into binary representation. This included columns like 'gender', 'parent_educ', 'lunch_type', 'test_prep', 'parent_marital_status', 'practice_sport', 'is_first_child', 'transport_means', and 'wkly_study_hours'.
# 3. **Risk Category:** We created a new column 'risk_cat' to identify students who had a final score less than or equal to 75. This will help in identifying students who might be at risk academically.
# 4. **Data Export:** Finally, we exported the preprocessed data into a new CSV file for further analysis.
#
# ### These preprocessing steps will help in the next steps of our analysis where we will build predictive models to identify students at risk based on social characteristics.
